# %% [markdown]
# # Problems 2

# %% [markdown]
# Name: Denitsa Ilieva

# %% [markdown]
# ## Problem 1
# A set $C$ is said to be convex iff for all $x,y \in C$ and $\theta \in \mathbb{R}$ where $0 \leq \theta \leq 1$:
# $$
# \theta x +(1-\theta)y \in C.
# $$
#
# For this problem, graphical solutions are allowed, but if you give a graphical solution, you must provide a natural language explanation (1-2 sentences) why your depiction is an actual solution of the exercise.

# %% [markdown]
# 1. Show that the union of convex sets is not necessarily a convex set.

# %% [markdown]
# **Solution:**
#
# In diesem Fall gehören die beiden Punkte zu der Menge, aber die Verbindungssträcke liegt nicht völlig in der Menge, wie in dem Beispiel unten.
# ![nicht_konvexe_Menge.PNG](data:image/png;base64,...)

# %% [markdown]
# 2. Show that the intersection of convex sets always is a convex set.

# %% [markdown]
# **Solution:**
#
# Let C1, · · · , Ck be convex sets, and define C := ∩Ck. Assume x, y ∈ C
# and λ ∈ [0, 1]. By definition of C we have x, y ∈ Ci
# , i ∈ {1, · · · , k}, and by
# convexity we have λx+(1−λ)y ∈ Ci
# , i ∈ {1, · · · , k}. This means λx+(1−λ)y ∈ C,
# so C is convex.

# %% [markdown]
# 3. Show that the 0-1 loss function is not convex, using the definition
# $$
#   f(x) = \left\{
#   \begin{array}{ll}
#     1 & \mbox{ if } x \leq 0 \\
#     0 & \mbox{ else }
#   \end{array}
#   \right.
# $$
#   and the convexity condition
# $$
#   \forall x, y, \alpha \textrm{ s.t. } 0 \leq \alpha \leq 1: f(\alpha x + (1-\alpha) y) \leq \alpha f(x) + (1-\alpha) f(y)
# $$

# %% [markdown]
# **Solution:**
#
# Assume, that $$ (x,y, \lambda ) = (-1,1,\frac{1}{2})\\
#  	{\displaystyle \Rightarrow } \; f(-\frac{1}{2} + \frac{1}{2}) \leq \frac{1}{2}f(-1) + \frac{1}{2}f(1) \\
#    {\displaystyle \Leftrightarrow } \\
#    1 \leq \frac{1}{2}\\
#    {\displaystyle \Rightarrow } $$ the 0-1 loss function is not convex

# %% [markdown]
# ## Problem 2

# %% [markdown]
# 1. Apply the chain rule to calculate the derivative of the function $f(x) = \exp(x^2)$.

# %% [markdown]
# **Solution:**
# $$
# f'(x) = exp(x^2)2x
# $$

# %% [markdown]
# 2. Calculate the gradient $\nabla f(x)$ for the following function $f:\mathbb{R}^3 \rightarrow \mathbb{R}$:
# $$
# f(x) = \frac{1}{2}x_1^4 + 25 x_2^2 - 3 x_1 x_2 x_3
# $$

# %% [markdown]
# **Solution:**
#
# $$
# \nabla f(x) = (2x_{1}^3-3x_{2}x{3},\ 50x_{2}-3x_{1}x_{3},\ -3x_{1}x_{2})
# $$

# %% [markdown]
# ## Problem 3
# Consider the following function $f:\mathbb{R}^2 \rightarrow \mathbb{R}$ where $f(\mathbf{x}) = x_1^2+x_2^2$.

# %% [markdown]
# 1. Calculate its gradient $\nabla f(x)$

# %% [markdown]
# **Solution:**
#
# $$
# \nabla f(x) = (2x_{1}, \ 2x_{2})
# $$

# %% [markdown]
# 2. Draw the level curves $f(x) = c$ for $c \in \{1,2,3,4\}$. <br> Hint: Level curves visualise level sets, which are defined as in https://en.wikipedia.org/wiki/Level_set

# %% [markdown]
# die richtigen Punkte auf dem Kreis liegen auf $1,\sqrt2,\sqrt3,2$

# %% [markdown]
# **Solution:**
# ![levelsets.PNG](data:image/png;base64,...)

# %% [markdown]
# 3. Pick a point on a level curve. Calculate and draw the gradient at that point. Only the direction of the gradient is important, not its length.

# %% [markdown]
# **Solution:**
#
# Pick a point (1,2)
#
# $$
# f(x_{1}, x_{2})= 1^2 + 2^2 = 5\\
# \nabla f(x) = <2, 4>
# $$
#
# We have to show that $\nabla f(1,2)$ is orthogonal to $f(x_{1},x_{2})$ <br>
# The difference: $$fx_{1}(x_{1},x_{2}) + fx_{2}(x_{1},x_{2})\frac{dx_{2}}{dx_{1}} = 0$$
#
# Slope the tangent line: $$ m = \frac{\nabla x_{2}}{\nabla x_{1}} = \frac{fx_{2}(a,b)}{fx_{1}(a,b)}$$
#
# $$
# x_{1}^2 + x_{2}^2 = 5 \ {\displaystyle \Rightarrow } \ 2x_{1} + 2x_{2}\frac{dx_{2}}{dx_{1}} = 0$$ at point (1,2) <br>
#
# $$
# 2 + 4\frac{dx_{2}}{dx_{1}} = 0 \\
# \frac{dx_{2}}{dx_{1}} = -\frac{1}{2} \\
# m = 2
# $$
#
# For the normal line we go through the point (1,2) in the direction of the gradient <2,4> (See the figure below)

# %% [markdown]
# ![direction.PNG](data:image/png;base64,...)
