# %% [markdown]
# # Problems 4

# %% [markdown]
# Name: Denitsa Ilieva

# %% [markdown]
# ## Problem 1
# Logistic regression for binary classification where $\mathcal{Y} = \{-1, +1\}$ is defined by the following probability model:
# $$
# P(y_i|x_i) = \frac{1}{1 + e^{-y_i \; \omega \cdot \phi(x_i)}}
# $$

# %% [markdown]
# Show how to derive this model from the multiclass logistic regression model
# $$
# P(y_i|x_i) = \frac{e^{\omega \cdot \phi(x_i,y_i)}}{\sum_{y \in Y} e^{\omega \cdot \phi(x_i,y)}}
# $$
# by setting $\phi(x,y) = \frac{1}{2} y \phi(x)$.

# %% [markdown]
# **Solution:**
#
# Because we have 2 classes, we can simplify the formula:
#
# $$
# p_{1} = \frac{e^{ω \cdot y_{1} \phi(x_{1})}}{e^{ω \cdot y_{0} \phi(x_{0})} + e^{ω \cdot y_{1} \phi(x_{1})}} = \frac{e^{ω \cdot y_{1} \phi(x_{1})}}{e^{ω \cdot y_{0} \phi(x_{0})} + e^{ω \cdot y_{1} \phi(x_{1})}} \cdot \frac{e^{ω \cdot y_{1} \phi(x_{1})}}{e^{ω \cdot y_{1} \phi(x_{1})}}\\
# =\frac{1}{\frac{e^{ω \cdot y_{0} \phi(x_{0})}}{e^{ω \cdot y_{1} \phi(x_{1})}}+1} = \frac{1}{e^{ω \cdot y_{0} \phi(x_{0}) - ω \cdot y_{1} \phi(x_{1})} + 1}\\
# =\frac{1}{1 + e^{ω(y_{0} \phi x_{0} -y_{1} \phi x_{1})}} = \frac{1}{1 + e^{-y_{i}ω \phi x_{i}}}
# $$

# %% [markdown]
# ## Problem 2
# The objective function for binary classification logistic regression is also called the *log-loss* function, defined for $\mathcal{Y} = \{-1, +1\}$ as
# $$
# \sum_i \log (1 + e^{-y_i \; \omega \cdot \phi(x_i)}).
# $$
# Show how to derive this objective from a maximum-likelihood objective for binary classification logistic regression.

# %% [markdown]
# **Solution:**
#
# Derive log-loss function from MLE:
#
# $$
# 𝒫 = argmax \sum log \frac{1}{1 + e^{-y_i \; \omega \cdot \phi(x_i)}}\\
# =argmin -\sum log \frac{1}{1 + e^{-y_i \; \omega \cdot \phi(x_i)}}\\
# =argmin \sum log(1 + e^{-y_i \; \omega \cdot \phi(x_i)})
# $$

# %% [markdown]
# ## Problem 3
# Comparing Naive Bayes to Logistic Regression from the perspective of generative vs. discriminative models: What are possible advantages of generative models such as Naive Bayes?

# %% [markdown]
# **Solution:**
#
# A **generative model** like naive Bayes makes use of the likelihood term, which generative model expresses how to generate the features of a document if we knew it was of class c.</br>
# geberate ouput and input </br>
# optimizing a joint probability allows to marginalize out p(y) a traet x as latent variable e.g. i parsing-based naguage modeling where x=parse, y= sentence </br>
# without learning rate </br>
# It is usually easy to fit generative classifiers, e.g. by simply counting and averaging. With generative model we can deal easy with missing data. We can run generative models backwards.
#
# A **discriminative model** attempts to directly compute P(y|x). Perhaps it will learn to assign a high weight to document features that directly improve its ability to discriminate between possible classes, even if it couldn’t generate an example of one of the classes.
